# %% [markdown]
# # Install Library

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB 1.4 MB/s eta 0:00:05
#     --------------------------------------- 0.1/6.8 MB 1.3 MB/s eta 0:00:06
#    - -------------------------------------- 0.2/6.8 MB 1.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/6.8 MB 1.8 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/6.8 MB 2.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.5/6.8 MB 2.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.6/6.8 MB 2.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.7/6.8 MB 2.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/6.8 MB 2.0 MB/s eta 0:00:04
# ...

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load Data

# %%
path = "D:\Python - AIT2003 1\Final Project__22022564\Data\zoeyphuong124_raw.npy"
post_list = np.load(path, allow_pickle=True)
post_df_full = pd.read_excel("D:\Python - AIT2003 1\Final Project__22022564\Data\zoeyphuong124_raw.xlsx")

# %%
post_df_omitted = post_df_full[['post_id','text', 'time', 'timestamp', 'comments', 'shares', 'post_url', 'links', 'user_id', 'username', 'user_url', 'comments_full', 'reactions', 'reaction_count']]

# %%
# Show first 5 post after omit 
post_df_omitted.head(5)
# Out:
#            post_id                                               text  \
# 0  884944059658138  Chuyện yêu người nhạy cảm\n\nSau một thời gian...
# 1  878691913616686  Rizz không hay nhưng cũng tạm ổn đến từ Duy Ph...
# 2  877796960372848  Trời sắp lạnh rồi, liệu mình có thể để răng ha...
# 3  877028770449667  Mai tháng 11, mời anh em cốc nâu lắc:\nNâu lắc...
# 4  875725880579956  Babi ơi, tất cả những gì được đánh lên mặt em ...
#
#                  time   timestamp  comments  shares  \
# 0 2023-11-16 09:21:18  1700101278       269    1546
# 1 2023-11-03 17:52:15  1699008735        46     155
# 2 2023-11-01 21:32:08  1698849128        80      64
# 3 2023-10-31 11:18:07  1698725887       442     237
# 4 2023-10-28 22:26:27  1698506787       253     486
#
#                                             post_url  \
# 0  https://facebook.com/zoeyphuong124/posts/88494...
# 1  https://facebook.com/zoeyphuong124/posts/87869...
# 2  https://facebook.com/zoeyphuong124/posts/87779...
# ...

# %% [markdown]
# # Analyze the quantity of reactions by post

# %%
import pandas as pd
import matplotlib.pyplot as plt

def save_df_columns_as_image(df, path):
    # select columns
    columns_to_select = ['post_id', 'reactions']
    
    # create df with selected columns
    selected_df = df[columns_to_select]
    
    # calculate number of columns and rows
    num_columns = len(selected_df.columns)
    num_rows = len(selected_df)
    
    fig, ax = plt.subplots(figsize=(16, 12))  # edit size of picture
    ax.axis('off')  # hide the axis 
    
    # create a table from df and draw it
    table = ax.table(cellText=selected_df.values, colLabels=selected_df.columns,
                     cellLoc='center', loc='center', colColours=['#f3f3f3']*num_columns)
    
    # edit size of data in table
    table.auto_set_font_size(False)
    table.set_fontsize(8)
    
   # edit width of each column 
    col_widths = [0.5, 0.5]  
    
    # set width of each column
    for i, col_width in enumerate(col_widths):
        for cell in table.get_celld().values():
            if cell.get_text().get_text() == selected_df.columns[i]:
                cell.set_width(col_width)
  
    # save the picture
    plt.savefig(path, bbox_inches='tight', pad_inches=0.5)

save_df_columns_as_image(post_df_omitted, "D:\Python - AIT2003 1\Final Project__22022564\Data\\")

# %%
post_df_omitted[['post_id', 'reactions']]
# Out:
#              post_id                                          reactions
# 0    884944059658138  {'thích': 2949, 'yêu thích': 1473, 'haha': 4, ...
# 1    878691913616686  {'thích': 969, 'yêu thích': 29, 'haha': 325, '...
# 2    877796960372848  {'thích': 1226, 'yêu thích': 14, 'haha': 418, ...
# 3    877028770449667  {'thích': 4682, 'yêu thích': 43, 'haha': 2342,...
# 4    875725880579956  {'thích': 6640, 'yêu thích': 949, 'haha': 1704...
# ..               ...                                                ...
# 126  715803356572210  {'thích': 1222, 'yêu thích': 8, 'haha': 425, '...
# 127  715501139935765  {'thích': 483, 'yêu thích': 54, 'haha': 173, '...
# 128  715089326643613  {'thích': 5260, 'yêu thích': 84, 'haha': 2516,...
# 129  714837060002173  {'thích': 1276, 'yêu thích': 14, 'haha': 670, ...
# 130  714417146710831  {'thích': 1818, 'yêu thích': 67, 'haha': 35, '...
#
# [131 rows x 2 columns]

# %% [markdown]
# # Analyze the quantity of reactions over time based on post's publication

# %%
post_df_omitted[['time', 'timestamp', 'reaction_count']]
# Out:
#                    time   timestamp  reaction_count
# 0   2023-11-16 09:21:18  1700101278            4537
# 1   2023-11-03 17:52:15  1699008735            1382
# 2   2023-11-01 21:32:08  1698849128            1820
# 3   2023-10-31 11:18:07  1698725887            7803
# 4   2023-10-28 22:26:27  1698506787            9467
# ..                  ...         ...             ...
# 126 2023-01-10 23:32:29  1673368349            1772
# 127 2023-01-10 12:18:54  1673327934             726
# 128 2023-01-09 19:47:13  1673268433            9090
# 129 2023-01-09 09:45:08  1673232308            2247
# 130 2023-01-08 17:58:41  1673175521            1972
#
# [131 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

def save_df_columns_as_image(df, path):
    # select columns
    columns_to_select = ['time', 'timestamp', 'reaction_count']
    
    # create df with selected columns
    selected_df = df[columns_to_select]
    
    # calculate number of columns and rows
    num_columns = len(selected_df.columns)
    num_rows = len(selected_df)
    
    fig, ax = plt.subplots(figsize=(16, 12))  # edit size of picture
    ax.axis('off')  # hide the axis 
    
    # create a table from df and draw it
    table = ax.table(cellText=selected_df.values, colLabels=selected_df.columns,
                     cellLoc='center', loc='center', colColours=['#f3f3f3']*num_columns)
    
    # edit size of data in table
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    
   # edit width of each column 
    col_widths = [0.3333333333, 0.3333333333, 0.3333333333]  
    
    # set width of each column
    for i, col_width in enumerate(col_widths):
        for cell in table.get_celld().values():
            if cell.get_text().get_text() == selected_df.columns[i]:
                cell.set_width(col_width)
  
    # save the picture
    plt.savefig(path, bbox_inches='tight', pad_inches=0.5)

save_df_columns_as_image(post_df_omitted, "D:\Python - AIT2003 1\Final Project__22022564\Data\\_")

# %% [markdown]
# # Establish a list of time stamp (from the farthest time to the present) and a list of reaction quantities (from the farthest time to the present)

# %%
# Dates: List of timestamp from post[0] to post[99]
dates = post_df_omitted['timestamp'].to_list()

# Reacts: List of reaction count from post[0] to post[99]
reacts = post_df_omitted['reaction_count'].to_list()

# Reverse dates and reacts
dates.reverse()
reacts.reverse()

print(len(dates), len(reacts))
print(dates)
print(reacts)
# reacts.sort()
# print(reacts)
# Out:
# 131 131
# ...

# %% [markdown]
# # Build a chart illustrating the reaction performance of posts over time, ranging from the furthest date to the present day

# %%
plt.plot(dates, reacts)
plt.show()

# %%
top_10_rows = post_df_omitted.nlargest(10, 'reaction_count')

time_with_top_reactions = top_10_rows[['time', 'text', 'reaction_count', 'post_url']]

print(f'Time with top 10 reactions:\n{time_with_top_reactions}')
# Out:
# Time with top 10 reactions:
#                    time                                               text  \
# 99  2023-04-19 09:39:03  Tại sao phải đến tận Tây Thiên khi ngày nào tô...
# 76  2023-06-27 22:15:49  Chúc các bạn 2k5\n7h30 sáng trúng đề\nKhông th...
# 113 2023-02-15 14:44:12                 Dị ứng với hải sản, cụ thể là trai
# 94  2023-04-24 21:17:16  Em bơ vơ giữa cánh đồng. Nhưng lại là cánh đồn...
# 122 2023-01-16 06:54:44  Em bảo em thích ngoài lạnh trong nóng\nTôi tặn...
# 67  2023-07-10 21:42:30  Sin đi học cos không hư tan đoàn kết\ncotanguv...
# 80  2023-05-12 13:03:57  Xưa đọc truyện có đoạn kể khi Yết Kiêu bị giặc...
# 4   2023-10-28 22:26:27  Babi ơi, tất cả những gì được đánh lên mặt em ...
# 128 2023-01-09 19:47:13  Lúc ra về em đừng hỏi anh đi đằng nào\nVì đằng...
# 79  2023-05-17 17:39:21     Có cái nóng nào bằng cái nóng lòng được gặp em
#
#      reaction_count                                           post_url
# ...

# %% [markdown]
# # Most common hours for Posting

# %%
# Extract the hour from the time column
post_df_with_hour = post_df_omitted.copy()
post_df_with_hour['hour'] = post_df_with_hour['time'].dt.hour


# Count the frequency of each hour
hour_counts = post_df_with_hour['hour'].value_counts()

# Plot the most common hours for posting
plt.figure(figsize=(10, 6))
sns.barplot(x=hour_counts.index, y=hour_counts.values, color='lightcoral')
plt.title('Most Common Hours for Posting')
plt.ylabel('Number of posts')
plt.xlabel('Hour')
# Out:
# Text(0.5, 0, 'Hour')

# %% [markdown]
# # Posting hour and Reactions

# %%
corr = post_df_with_hour[['reaction_count', 'comments', 'shares', 'hour']].corr()
sns.heatmap(corr, annot=True, cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
plt.scatter(post_df_with_hour['hour'], post_df_with_hour['reaction_count'], c=post_df_with_hour['reaction_count'], cmap='cool')
plt.title('Hour vs Reaction Count')
plt.xlabel('Hour')
plt.ylabel('Reaction Count')
plt.colorbar()

# %% [markdown]
# # Analyze each type of reactions

# %%
post_reacts = post_df_omitted.copy()
post_reacts['reactions'] = post_reacts['reactions'].apply(lambda x : dict(eval(x)))
post_df_full_reactions = post_reacts['reactions'].apply(pd.Series)
post_df_full_with_reactions = pd.concat([post_reacts, post_df_full_reactions], axis=1).drop('reactions', axis=1)
post_df_full_with_reactions[['text','thích','yêu thích','haha','wow','buồn','phẫn nộ','thương thương',
                                 'shares','comments','reaction_count']]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21192\2043888804.py:3: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   post_df_full_reactions = post_reacts['reactions'].apply(pd.Series)
#                                                   text   thích  yêu thích  \
# 0    Chuyện yêu người nhạy cảm\n\nSau một thời gian...  2949.0     1473.0
# 1    Rizz không hay nhưng cũng tạm ổn đến từ Duy Ph...   969.0       29.0
# 2    Trời sắp lạnh rồi, liệu mình có thể để răng ha...  1226.0       14.0
# 3    Mai tháng 11, mời anh em cốc nâu lắc:\nNâu lắc...  4682.0       43.0
# 4    Babi ơi, tất cả những gì được đánh lên mặt em ...  6640.0      949.0
# ..                                                 ...     ...        ...
# 126  Mẹ cứ giục đi xem mắt\nMắt thôi thì xem làm gì...  1222.0        8.0
# 127  Năm tháng cứ tưởng giấc chiêm bao\nDông qua xu...   483.0       54.0
# ...

# %%
for i in range(0, len(post_df_full_with_reactions['thích'].values), 1):
    if pd.isna(post_df_full_with_reactions['thích'].values[i]):
        post_df_full_with_reactions['thích'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['yêu thích'].values[i]):
        post_df_full_with_reactions['yêu thích'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['haha'].values[i]):
        post_df_full_with_reactions['haha'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['wow'].values[i]):
        post_df_full_with_reactions['wow'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['buồn'].values[i]):
        post_df_full_with_reactions['buồn'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['phẫn nộ'].values[i]):
        post_df_full_with_reactions['phẫn nộ'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['thương thương'].values[i]):
        post_df_full_with_reactions['thương thương'].values[i] = 0

    if pd.isna(post_df_full_with_reactions['shares'].values[i]):
        post_df_full_with_reactions['shares'].values[i] = 0
    
    if pd.isna(post_df_full_with_reactions['comments'].values[i]):
        post_df_full_with_reactions['comments'].values[i] = 0

post_df_full_with_reactions[['text','thích','yêu thích','haha','wow','buồn','phẫn nộ','thương thương',
                                 'shares','comments','reaction_count']]
# Out:
#                                                   text   thích  yêu thích  \
# 0    Chuyện yêu người nhạy cảm\n\nSau một thời gian...  2949.0     1473.0
# 1    Rizz không hay nhưng cũng tạm ổn đến từ Duy Ph...   969.0       29.0
# 2    Trời sắp lạnh rồi, liệu mình có thể để răng ha...  1226.0       14.0
# 3    Mai tháng 11, mời anh em cốc nâu lắc:\nNâu lắc...  4682.0       43.0
# 4    Babi ơi, tất cả những gì được đánh lên mặt em ...  6640.0      949.0
# ..                                                 ...     ...        ...
# 126  Mẹ cứ giục đi xem mắt\nMắt thôi thì xem làm gì...  1222.0        8.0
# 127  Năm tháng cứ tưởng giấc chiêm bao\nDông qua xu...   483.0       54.0
# 128  Lúc ra về em đừng hỏi anh đi đằng nào\nVì đằng...  5260.0       84.0
# 129  Tôi nhận ra mình già khi có em gái hỏi\n"Anh t...  1276.0       14.0
# 130  Em cứ nói những gì em muốn\nnhưng chưa chắc em...  1818.0       67.0
#
#        haha  wow    buồn  phẫn nộ  thương thương  shares  comments  \
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['thích'], label = "Like", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['yêu thích'], label = "Love", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['haha'], label = "Ha Ha", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['wow'], label = "Wow", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['buồn'], label = "Sad", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['phẫn nộ'], label = "Angry", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['thương thương'], label = "Care", marker="o")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['shares'], label = "Shares", marker="s")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['comments'], label = "Comments", marker="*")
ax.plot(post_df_full_with_reactions['time'], post_df_full_with_reactions['comments'], label = "reaction_count", marker="*")

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
print(post_df_full_with_reactions[['thích','yêu thích','haha','wow','buồn','phẫn nộ','thương thương']].corrwith(post_df_full_with_reactions['shares']))
# Out:
# thích            0.482555
# yêu thích        0.519531
# haha             0.501546
# wow              0.424399
# buồn             0.274606
# phẫn nộ          0.182879
# thương thương    0.745046
# dtype: float64
